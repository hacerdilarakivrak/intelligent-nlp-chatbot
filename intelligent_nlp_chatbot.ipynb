# %%
import numpy as np
import tensorflow as tf
import random

seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
data = {
    "greeting": [
        "hello",
        "hi",
        "hey",
        "good morning",
        "good afternoon",
        "good evening",
        "hi there",
        "hello there",
        "hey buddy",
        "what's up",
        "how are you",
        "nice to meet you",
        "greetings",
        "hey there",
        "hello my friend",
        "hi how are you",
        "good to see you",
        "hey how is it going",
        "hello again",
        "hi everyone",
        "hey what's going on",
        "hi there how are you",
        "hello buddy",
        "good day",
        "hey how are things",
        "hi my friend",
        "hello assistant",
        "hi assistant",
        "hey assistant",
        "good morning assistant",
        "hello how is your day",
        "hey good to see you",
        "hi nice to meet you",
        "hello nice to see you",
        "greetings assistant",
        "hey how are you doing",
        "hi chatbot",
        "hello chatbot",
        "good evening assistant",
        "hello dear assistant",
        "hi there assistant",
        "hey friend",
        "good morning my assistant",
        "nice meeting you",
        "hello how are things",
        "hi good morning",
        "hey nice to meet you",
        "hello once again",
        "hi and good evening",
        "greetings my friend"
    ],

    "goodbye": [
        "bye",
        "goodbye",
        "see you later",
        "see you",
        "take care",
        "bye bye",
        "talk to you later",
        "catch you later",
        "have a nice day",
        "see you soon",
        "good night",
        "farewell",
        "see you next time",
        "i have to go",
        "have a good day",
        "take it easy",
        "talk soon",
        "see you tomorrow",
        "bye for now",
        "until next time",
        "see ya",
        "i am leaving now",
        "goodbye my friend",
        "have a great day",
        "see you again",
        "i will talk to you later",
        "bye assistant",
        "goodbye assistant",
        "see you later assistant",
        "i need to leave now",
        "have a wonderful day",
        "i am going now",
        "let's talk later",
        "see you around",
        "bye see you soon",
        "good night assistant",
        "i will come back later",
        "thanks goodbye",
        "alright bye",
        "okay see you later",
        "have a nice evening",
        "i should go now",
        "bye my friend",
        "see you next time assistant",
        "it was nice talking to you goodbye",
        "i am done for now bye",
        "talk to you again later",
        "see you very soon",
        "bye and take care",
        "goodbye for now"
    ],

    "help": [
        "can you help me",
        "i need help",
        "what can you do",
        "how can you help me",
        "help me please",
        "i need some assistance",
        "what are your features",
        "what do you do",
        "can you assist me",
        "give me information",
        "i want some help",
        "please help me",
        "can you support me",
        "what services do you provide",
        "tell me what you can do",
        "i need your help",
        "could you help me",
        "can you guide me",
        "i need some information",
        "show me your abilities",
        "how do you work",
        "what can you help with",
        "help me understand",
        "can you explain things",
        "what are you capable of",
        "i want to learn what you do",
        "please guide me",
        "can you give me support",
        "i need guidance",
        "can you explain your functions",
        "tell me your features",
        "what kind of help can you provide",
        "can you provide assistance",
        "please assist me",
        "how do you assist users",
        "i need some guidance",
        "show me how you can help",
        "what can i ask you",
        "can you explain what you do",
        "help me with this",
        "could you guide me",
        "can you offer support",
        "i need help right now",
        "please tell me how you can help",
        "what exactly can you do",
        "how may you help me",
        "what tasks can you perform",
        "can you be of assistance",
        "please provide help",
        "i want your assistance"
    ],

    "time_query": [
        "what time is it",
        "tell me the time",
        "current time please",
        "can you tell me the time",
        "what is the time now",
        "time please",
        "do you know the time",
        "give me the current time",
        "what time is it now",
        "i want to know the time",
        "could you tell me the time",
        "may i know the time",
        "what is the current time",
        "please tell me the time",
        "tell me the current time",
        "can i know the time",
        "what time do we have now",
        "show me the time",
        "let me know the time",
        "time right now",
        "tell me what time it is",
        "can you give me the time",
        "current time now",
        "please tell me the current time",
        "what is the exact time",
        "what time do you have",
        "do you know what time it is",
        "can you show the time",
        "i need the current time",
        "tell me the exact time",
        "what time is it right now",
        "please show me the time",
        "can you say the time",
        "let me know the current time",
        "i want the exact time",
        "what is the time",
        "tell me time",
        "can you tell me current time",
        "show the current time",
        "what's the time now",
        "what's the current time",
        "could you give me the current time",
        "please give me the time",
        "i would like to know the time",
        "time information please",
        "tell me the time now",
        "what is the clock now",
        "current time information",
        "can i get the time",
        "give me time information"
    ],

    "weather_query": [
        "how is the weather",
        "what is the weather today",
        "is it raining",
        "weather forecast",
        "is it sunny today",
        "tell me the weather",
        "what's the weather like",
        "is it cold outside",
        "weather information please",
        "how's the weather today",
        "what is the forecast",
        "will it rain today",
        "is it hot outside",
        "give me the weather report",
        "tell me today's weather",
        "what is the temperature",
        "is the weather nice today",
        "how does the weather look",
        "do i need an umbrella",
        "is it windy outside",
        "what's the temperature today",
        "is it going to snow",
        "weather update please",
        "tell me the forecast",
        "how is outside weather",
        "what is the weather like today",
        "can you give me the forecast",
        "is the weather sunny",
        "will the weather be cold",
        "is it warm outside",
        "tell me if it will rain",
        "how hot is it today",
        "how cold is it outside",
        "do i need a jacket today",
        "what does the weather look like",
        "is it cloudy today",
        "will it be sunny",
        "can you tell me today's forecast",
        "give me weather information",
        "what is today's forecast",
        "is the temperature high today",
        "is the temperature low today",
        "what is the outside temperature",
        "weather details please",
        "forecast for today please",
        "how is the temperature today",
        "is today a rainy day",
        "is it freezing outside",
        "will it be windy today",
        "weather status please"
    ],

    "course_info": [
        "what is my schedule",
        "do i have a class today",
        "when is my exam",
        "what classes do i have",
        "show my timetable",
        "what is my course plan",
        "do i have homework",
        "when is the next class",
        "tell me my schedule",
        "what lessons do i have",
        "what is today's schedule",
        "is there any class today",
        "when is my next lesson",
        "do i have any assignments",
        "show me my class schedule",
        "what subjects do i have",
        "when is the homework due",
        "what is my exam date",
        "tell me about my courses",
        "what is on my timetable",
        "what is my class schedule today",
        "do i have lectures today",
        "when are my classes",
        "what courses am i taking",
        "what is my next exam",
        "show me today's classes",
        "do i have an exam this week",
        "when is the next lecture",
        "what homework do i have",
        "show me my assignments",
        "what is my lesson plan",
        "do i have any class tomorrow",
        "when is my homework due",
        "tell me my class plan",
        "what courses do i have today",
        "show me my weekly schedule",
        "what is my university schedule",
        "when is the assignment deadline",
        "do i have a lecture today",
        "what classes are scheduled today",
        "tell me my exam schedule",
        "what are my subjects",
        "do i have any quizzes",
        "what is tomorrow's timetable",
        "show my exam dates",
        "when is the next assignment due",
        "what is my academic schedule",
        "do i have school today",
        "what lessons are planned today",
        "show my course timetable"
    ],

    "thanks": [
        "thank you",
        "thanks",
        "thanks a lot",
        "thank you so much",
        "many thanks",
        "thanks for your help",
        "i appreciate it",
        "thank you very much",
        "thanks buddy",
        "thanks assistant",
        "that was helpful thanks",
        "thank you for helping me",
        "i really appreciate it",
        "thanks for the information",
        "thank you for your support",
        "thanks a bunch",
        "thanks a million",
        "thank you my friend",
        "much appreciated",
        "thanks for everything",
        "thank you kindly",
        "i appreciate your help",
        "thanks for your assistance",
        "thanks that helped me",
        "thank you for the guidance",
        "great thanks",
        "okay thanks",
        "awesome thanks",
        "perfect thank you",
        "thanks for explaining",
        "thank you for your time",
        "thanks that was useful",
        "i am grateful",
        "thanks for the response",
        "thank you that was great",
        "many thanks for your help",
        "i appreciate the support",
        "thank you assistant",
        "thanks a lot for that",
        "thanks for being helpful",
        "thank you so much assistant",
        "i really appreciate your support",
        "that is very helpful thank you",
        "thank you for the answer",
        "thanks for clarifying",
        "i appreciate your assistance",
        "thanks for the explanation",
        "thank you very much indeed",
        "thanks so much",
        "thank you for your assistance"
    ],

    "identity": [
        "who are you",
        "what are you",
        "what is your name",
        "tell me your name",
        "who am i talking to",
        "are you a chatbot",
        "are you an assistant",
        "introduce yourself",
        "what should i call you",
        "tell me about yourself",
        "what kind of assistant are you",
        "are you a bot",
        "what is your role",
        "who is this",
        "can you introduce yourself",
        "say your name",
        "i want to know who you are",
        "what do people call you",
        "what are you exactly",
        "who created you",
        "what is your purpose",
        "are you human",
        "are you real",
        "what can i call you",
        "tell me who you are",
        "who are you exactly",
        "what are you supposed to do",
        "are you an ai",
        "are you artificial intelligence",
        "what is your identity",
        "what kind of bot are you",
        "please introduce yourself",
        "who am i speaking with",
        "tell me your identity",
        "what do you call yourself",
        "what is your job",
        "what is your function",
        "what sort of assistant are you",
        "are you a virtual assistant",
        "who made you",
        "what do you represent",
        "what is your main purpose",
        "are you a real person",
        "can you tell me your name",
        "tell me what you are",
        "who exactly are you",
        "what are you designed for",
        "what is your assistant name",
        "what is your chatbot name",
        "who is the assistant"
    ]
}

# %%
sentences = []
labels = []

for intent, examples in data.items():
    for example in examples:
        sentences.append(example)
        labels.append(intent)

print("Number of sentences:", len(sentences))
print("Number of labels:", len(set(labels)))
print(set(labels))
# Out:
# Number of sentences: 400
# Number of labels: 8
# {'help', 'thanks', 'goodbye', 'weather_query', 'greeting', 'identity', 'time_query', 'course_info'}

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)

max_len = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)
categorical_labels = to_categorical(encoded_labels)

print("Max length:", max_len)
print("Vocabulary size:", len(tokenizer.word_index) + 1)
print("X shape:", padded_sequences.shape)
print("y shape:", categorical_labels.shape)
# Out:
# Max length: 7
# Vocabulary size: 249
# X shape: (400, 7)
# y shape: (400, 8)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences,
    categorical_labels,
    test_size=0.2,
    random_state=42
)

print("Train samples:", len(X_train))
print("Test samples:", len(X_test))
# Out:
# Train samples: 320
# Test samples: 80

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, GlobalAveragePooling1D, Dense, Dropout

vocab_size = len(tokenizer.word_index) + 1
num_classes = len(label_encoder.classes_)

model = Sequential([
    Input(shape=(max_len,)),
    Embedding(input_dim=vocab_size, output_dim=64),
    GlobalAveragePooling1D(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 7, 64)          │        15,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=70,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.2094 - loss: 2.0743 - val_accuracy: 0.2500 - val_loss: 2.0678
# Epoch 2/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3344 - loss: 2.0567 - val_accuracy: 0.2250 - val_loss: 2.0511
# Epoch 3/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4000 - loss: 2.0299 - val_accuracy: 0.2750 - val_loss: 2.0237
# Epoch 4/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4344 - loss: 1.9916 - val_accuracy: 0.3250 - val_loss: 1.9761
# Epoch 5/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4938 - loss: 1.9250 - val_accuracy: 0.3625 - val_loss: 1.9060
# Epoch 6/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5562 - loss: 1.8305 - val_accuracy: 0.3750 - val_loss: 1.8068
# Epoch 7/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6062 - loss: 1.7020 - val_accuracy: 0.4375 - val_loss: 1.6767
# Epoch 8/70
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.1131
# Test Loss: 0.11310327053070068
# Test Accuracy: 0.9750000238418579

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.title("Model Accuracy")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step

# %%
y_true = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_true, y_pred_classes)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np

def predict_intent(text):
    seq = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(seq, maxlen=max_len, padding='post')
    prediction = model.predict(padded, verbose=0)
    predicted_index = np.argmax(prediction)
    predicted_label = label_encoder.inverse_transform([predicted_index])[0]
    return predicted_label

# %%
print(predict_intent("hello"))
print(predict_intent("what time is it"))
print(predict_intent("thank you"))
print(predict_intent("who are you"))
# Out:
# greeting
# time_query
# thanks
# identity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

X_text = sentences
y_text = labels

X_train_text, X_test_text, y_train_text, y_test_text = train_test_split(
    X_text,
    y_text,
    test_size=0.2,
    random_state=42
)

tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2))
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train_text)
X_test_tfidf = tfidf_vectorizer.transform(X_test_text)

tfidf_model = LogisticRegression(max_iter=1000)
tfidf_model.fit(X_train_tfidf, y_train_text)

y_pred_tfidf = tfidf_model.predict(X_test_tfidf)

tfidf_accuracy = accuracy_score(y_test_text, y_pred_tfidf)
print("TF-IDF + N-gram Accuracy:", tfidf_accuracy)
# Out:
# TF-IDF + N-gram Accuracy: 0.975

# %%
print(classification_report(y_test_text, y_pred_tfidf))
# Out:
#                precision    recall  f1-score   support
#
#   course_info       1.00      1.00      1.00        10
#       goodbye       1.00      1.00      1.00        13
#      greeting       1.00      0.92      0.96        13
#          help       1.00      0.91      0.95        11
#      identity       0.87      1.00      0.93        13
#        thanks       1.00      1.00      1.00         5
#    time_query       1.00      1.00      1.00         7
# weather_query       1.00      1.00      1.00         8
#
#      accuracy                           0.97        80
#     macro avg       0.98      0.98      0.98        80
#  weighted avg       0.98      0.97      0.98        80

# %%
def predict_intent_tfidf(text):
    text_tfidf = tfidf_vectorizer.transform([text])
    prediction = tfidf_model.predict(text_tfidf)
    return prediction[0]

print(predict_intent_tfidf("hello"))
print(predict_intent_tfidf("what time is it"))
print(predict_intent_tfidf("thank you"))
print(predict_intent_tfidf("who are you"))
# Out:
# greeting
# time_query
# thanks
# identity

# %%
print("Neural Network Accuracy:", accuracy)
print("TF-IDF + N-gram Accuracy:", tfidf_accuracy)
# Out:
# Neural Network Accuracy: 0.9750000238418579
# TF-IDF + N-gram Accuracy: 0.975

# %%
import matplotlib.pyplot as plt

models = ['Neural Network', 'TF-IDF + N-gram']
accuracies = [accuracy, tfidf_accuracy]

plt.bar(models, accuracies)
plt.title('Model Comparison')
plt.ylabel('Accuracy')
plt.ylim(0.9, 1.0)
plt.show()

# %%
# !pip install gradio

# %%
import gradio as gr
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

responses = {
    "greeting": "Hello! How can I help you?",
    "goodbye": "Goodbye! Have a great day.",
    "help": "I can help you with greetings, time queries, weather queries, course information, identity questions, and thanks.",
    "time_query": "This looks like a time-related question.",
    "weather_query": "This looks like a weather-related question.",
    "course_info": "This looks like a course-related question.",
    "thanks": "You’re welcome!",
    "identity": "I am an NLP-based intelligent chatbot."
}

def predict_intent(text):
    seq = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(seq, maxlen=max_len, padding='post')
    prediction = model.predict(padded, verbose=0)
    predicted_index = np.argmax(prediction)
    predicted_label = label_encoder.inverse_transform([predicted_index])[0]
    return predicted_label

def chatbot_app(user_input):
    intent = predict_intent(user_input)
    response = responses.get(intent, "I understood the intent, but no response is defined.")
    return response

demo = gr.Interface(
    fn=chatbot_app,
    inputs=gr.Textbox(lines=2, placeholder="Type your message here...", label="You"),
    outputs=gr.Textbox(label="Chatbot Response"),
    title="Intelligent NLP Chatbot",
    description="An intent detection chatbot built with TensorFlow/Keras."
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4d52f008e5038bd1ea.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4d52f008e5038bd1ea.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
